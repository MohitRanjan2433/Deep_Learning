# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# '2022030027 (1).pdf'
# 'Assessment - 4.pdf'
#  bird_species.h5
#  CODECHEF_PRESENTA.pdf
#  CODECHEF_PRESENTA.pptx
# 'Colab Notebooks'
#  cott-plant-disease-pred.h5
#  Datasetsssss
# 'Event Registration.gform'
# 'Figma files.gdoc'
#  Hi
#  Party_Pic
#  provisionalDownload.pdf
# 'PRP 104'
#  Scanned_20230109-1659.pdf
#  Screenshot_2023-09-04-17-25-38-94_944a2809ea1b4cda6ef12d1db9048ed3.jpg
#  Screenshot_2023-09-04-17-25-44-70_944a2809ea1b4cda6ef12d1db9048ed3.jpg
#  ticket_7019222509.pdf
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document.docx'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
#  Wallp
#  Zaitoon

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook.
# Here you can see that I have 2 folders in my drive and 'Plant_images_pianlytix'  contains the images that we will work on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Collab+Code (4)/Collab Code/Data/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
# dir = "/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Collab+Code (4)/Collab Code/Data/Plant_images_pianalytix"
# root_dir = listdir(training_data)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 256, 256, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 85, 85, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 85, 85, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 42, 42, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 42, 42, 64)        0
#
#  flatten_1 (Flatten)         (None, 112896)            0
#
#  dense_2 (Dense)             (None, 8)                 903176
#
#  dense_3 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 922595 (3.52 MB)
# Trainable params: 922595 (3.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
history = model.fit(x_train, y_train, batch_size = 128, epochs = 50,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 51s 10s/step - loss: 1.0260 - accuracy: 0.4948 - val_loss: 0.8391 - val_accuracy: 0.6667
# Epoch 2/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.7707 - accuracy: 0.6354 - val_loss: 0.6288 - val_accuracy: 0.7083
# Epoch 3/50
# 5/5 [==============================] - 58s 12s/step - loss: 0.6300 - accuracy: 0.6597 - val_loss: 0.5319 - val_accuracy: 0.7014
# Epoch 4/50
# 5/5 [==============================] - 48s 9s/step - loss: 0.5524 - accuracy: 0.6597 - val_loss: 0.4790 - val_accuracy: 0.7083
# Epoch 5/50
# 5/5 [==============================] - 45s 9s/step - loss: 0.5160 - accuracy: 0.6615 - val_loss: 0.4516 - val_accuracy: 0.7083
# Epoch 6/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.4918 - accuracy: 0.6615 - val_loss: 0.4348 - val_accuracy: 0.7083
# Epoch 7/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.4764 - accuracy: 0.6632 - val_loss: 0.4203 - val_accuracy: 0.7083
# Epoch 8/50
# 5/5 [==============================] - 52s 11s/step - loss: 0.4619 - accuracy: 0.6649 - val_loss: 0.4078 - val_accuracy: 0.7083
# Epoch 9/50
# 5/5 [==============================] - 48s 9s/step - loss: 0.4487 - accuracy: 0.6649 - val_loss: 0.3922 - val_accuracy: 0.7083
# Epoch 10/50
# 5/5 [==============================] - 50s 9s/step - loss: 0.4344 - accuracy: 0.6632 - val_loss: 0.3773 - val_accuracy: 0.7083
# Epoch 11/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.4171 - accuracy: 0.6771 - val_loss: 0.3609 - val_accuracy: 0.7292
# Epoch 12/50
# 5/5 [==============================] - 48s 9s/step - loss: 0.3995 - accuracy: 0.7431 - val_loss: 0.3425 - val_accuracy: 0.8264
# Epoch 13/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.3801 - accuracy: 0.8646 - val_loss: 0.3218 - val_accuracy: 0.9306
# Epoch 14/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.3563 - accuracy: 0.8924 - val_loss: 0.3004 - val_accuracy: 0.9514
# Epoch 15/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.3351 - accuracy: 0.9045 - val_loss: 0.2794 - val_accuracy: 0.9583
# Epoch 16/50
# 5/5 [==============================] - 57s 12s/step - loss: 0.3143 - accuracy: 0.9115 - val_loss: 0.2590 - val_accuracy: 0.9792
# Epoch 17/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.2926 - accuracy: 0.9375 - val_loss: 0.2401 - val_accuracy: 0.9653
# Epoch 18/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.2733 - accuracy: 0.9288 - val_loss: 0.2238 - val_accuracy: 0.9792
# Epoch 19/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.2541 - accuracy: 0.9531 - val_loss: 0.2072 - val_accuracy: 0.9792
# Epoch 20/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.2356 - accuracy: 0.9688 - val_loss: 0.1911 - val_accuracy: 0.9792
# Epoch 21/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.2216 - accuracy: 0.9479 - val_loss: 0.1786 - val_accuracy: 0.9861
# Epoch 22/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.2033 - accuracy: 0.9809 - val_loss: 0.1638 - val_accuracy: 0.9861
# Epoch 23/50
# 5/5 [==============================] - 46s 9s/step - loss: 0.1896 - accuracy: 0.9670 - val_loss: 0.1491 - val_accuracy: 0.9931
# Epoch 24/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.1727 - accuracy: 0.9861 - val_loss: 0.1369 - val_accuracy: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.1555 - accuracy: 0.9792 - val_loss: 0.1226 - val_accuracy: 0.9931
# Epoch 26/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.1419 - accuracy: 0.9826 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.1266 - accuracy: 0.9913 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 53s 11s/step - loss: 0.1123 - accuracy: 0.9931 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 52s 10s/step - loss: 0.1018 - accuracy: 0.9896 - val_loss: 0.0788 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0980 - accuracy: 0.9896 - val_loss: 0.0722 - val_accuracy: 0.9931
# Epoch 31/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0875 - accuracy: 0.9844 - val_loss: 0.0635 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0786 - accuracy: 0.9913 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0737 - accuracy: 0.9931 - val_loss: 0.0532 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0656 - accuracy: 0.9913 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 47s 9s/step - loss: 0.0618 - accuracy: 0.9913 - val_loss: 0.0459 - val_accuracy: 0.9931
# Epoch 36/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.0609 - accuracy: 0.9913 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 50s 10s/step - loss: 0.0615 - accuracy: 0.9896 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0520 - accuracy: 0.9913 - val_loss: 0.0400 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 59s 12s/step - loss: 0.0520 - accuracy: 0.9931 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0487 - accuracy: 0.9913 - val_loss: 0.0348 - val_accuracy: 0.9931
# Epoch 41/50
# 5/5 [==============================] - 58s 10s/step - loss: 0.0425 - accuracy: 0.9948 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0421 - accuracy: 0.9965 - val_loss: 0.0317 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 47s 10s/step - loss: 0.0409 - accuracy: 0.9931 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0371 - accuracy: 0.9965 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0355 - accuracy: 0.9965 - val_loss: 0.0283 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0348 - accuracy: 0.9965 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.0338 - accuracy: 0.9948 - val_loss: 0.0249 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 49s 10s/step - loss: 0.0321 - accuracy: 0.9965 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 60s 12s/step - loss: 0.0308 - accuracy: 0.9965 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 52s 10s/step - loss: 0.0301 - accuracy: 0.9948 - val_loss: 0.0229 - val_accuracy: 0.9931

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 4s 602ms/step - loss: 0.0273 - accuracy: 1.0000
# Test Accuracy: 100.0

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 4s 600ms/step

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[78])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[72])])
print("Predicted : ",all_labels[np.argmax(y_pred[72])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# Printing out the original and the predicted label.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.

# %%
test_img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Collab+Code (4)/Collab Code/Data/Plant_images_pianalytix/Corn_(maize)___Common_rust_/RS_Rust 2471.JPG')

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (256, 256, 3)

# %%
test_input = test_img.reshape((1,256,256,3))

# %%
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[0., 1., 0.]], dtype=float32)
